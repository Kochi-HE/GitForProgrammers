# %%
'Snap'
# Out:
# 'Snap'

# %%
'Crackle'
# Out:
# 'Crackle'

# %%
"Nay!' said the naysayer. 'Neigh?' said the horse'"
# Out:
# "Nay!' said the naysayer. 'Neigh?' said the horse'"

# %%
'''Boom!'''
# Out:
# 'Boom!'

# %%
poem='''There was a Young Lady of Morway,
   Who casually sat in a doorway;
   When the door squeezed her flat,
   She exclaimed, "what of that?"
   This courageous Young Lady of Norway.
     '''
poem
# Out:
# 'There was a Young Lady of Morway,\n   Who casually sat in a doorway;\n   When the door squeezed her flat,\n   She exclaimed, "what of that?"\n   This courageous Young Lady of Norway.\n     '

# %%
print(poem)
# Out:
# There was a Young Lady of Morway,
#    Who casually sat in a doorway;
#    When the door squeezed her flat,
#    She exclaimed, "what of that?"
#    This courageous Young Lady of Norway.

# %%
print('Give',"us",'''some''',"""space""")
# Out:
# Give us some space

# %%
''
# Out:
# ''

# %%
""
# Out:
# ''

# %%
''''''
# Out:
# ''

# %%
""""""
# Out:
# ''

# %%
str(98.6)
# Out:
# '98.6'

# %%
str(1.0e4)
# Out:
# '10000.0'

# %%
str(True)
# Out:
# 'True'

# %%
palindrome = 'A man,\nA plan,\nA canal:\nPanama.'
print(palindrome)
# Out:
# A man,
# A plan,
# A canal:
# Panama.

# %%
print('\tabc')
# Out:
# 	abc

# %%
print('a\tbc')
# Out:
# a	bc

# %%
print('abc\t')
# Out:
# abc

# %%
testimony="\"I did nothing!\" he said. \"Or that other thing.\""
testimony
# Out:
# '"I did nothing!" he said. "Or that other thing."'

# %%
print(testimony)
# Out:
# "I did nothing!" he said. "Or that other thing."

# %%
fact = "The world's largest rubber duck was 54'2\" by 65'7\" by 105"
print(fact)
# Out:
# The world's largest rubber duck was 54'2" by 65'7" by 105

# %%
speech = 'The backlash (\\) bends over backwards to please you.'
print(speech)
# Out:
# The backlash (\) bends over backwards to please you.

# %%
info = r'Type a \n to get a new line in a normal string'
info
# Out:
# 'Type a \\n to get a new line in a normal string'

# %%
print(info)
# Out:
# Type a \n to get a new line in a normal string

# %%
poem = r'''Boys and girls, come out to play.
The moon doth shine as bright as day.'''
poem
# Out:
# 'Boys and girls, come out to play.\nThe moon doth shine as bright as day.'

# %%
"Release the kraken! "+'No, wait!'
# Out:
# 'Release the kraken! No, wait!'

# %%
"My world! " "A gentlman caller!"
# Out:
# 'My world! A gentlman caller!'

# %%
"Alas! ""The kraken!"
# Out:
# 'Alas! The kraken!'

# %%
vowels=('a'"e"'''i''''o'"""u""")
vowels
# Out:
# 'aeiou'

# %%
a='Duck. '
b=a
c='Grey Duck'
a+b+c
# Out:
# 'Duck. Duck. Grey Duck'

# %%
print(a+b+c)
# Out:
# Duck. Duck. Grey Duck

# %%
start='Na'*4+'\n'
middle='Hey'*3+'\n'
end='Goodbye.'
print(start+start+middle+end)
# Out:
# NaNaNaNa
# NaNaNaNa
# HeyHeyHey
# Goodbye.

# %%
letters='abcdefghijklmnopqrstuvwxyz'
letters[0]
# Out:
# 'a'

# %%
letters[1]
# Out:
# 'b'

# %%
letters[-1]
# Out:
# 'z'

# %%
letters[25]
# Out:
# 'z'

# %%
letters[5]
# Out:
# 'f'

# %% [markdown]
# #因字串是不可變的，所以無法將字元直接插入字串

# %%
name="Henny"
#name[0]="p"

# %%
name="Henny"
name.replace('','P')
# Out:
# 'Henny'

# %%
'P'+name[1:]
# Out:
# 'Penny'

# %%
latters="abcdefghijklmnopqrstuvwxyz"
letters[:]
# Out:
# 'abcdefghijklmnopqrstuvwxyz'

# %%
letters[20:]
# Out:
# 'uvwxyz'

# %%
letters[10:]
# Out:
# 'klmnopqrstuvwxyz'

# %%
letters[-3:]
# Out:
# 'xyz'

# %%
letters[18:-3]
# Out:
# 'stuvw'

# %%
letters[-6:-2]
# Out:
# 'uvwx'

# %%
letters[::7]
# Out:
# 'ahov'

# %%
letters[4:20:3]
# Out:
# 'ehknqt'

# %%
letters[19::4]
# Out:
# 'tx'

# %%
letters[:21:5]
# Out:
# 'afkpu'

# %%
letters[-1::-1]
# Out:
# 'zyxwvutsrqponmlkjihgfedcba'

# %%
letters[::-1]
# Out:
# 'zyxwvutsrqponmlkjihgfedcba'

# %%
letters[-50:]
# Out:
# 'abcdefghijklmnopqrstuvwxyz'

# %%
letters[-51:-50]
# Out:
# ''

# %%
letters[:70]
# Out:
# 'abcdefghijklmnopqrstuvwxyz'

# %%
letters[70:71]
# Out:
# ''

# %%
len(letters)
# Out:
# 26

# %%
empty=""
len(empty)
# Out:
# 0

# %%
tasks='get gloves,get cat vitamins,call ambukance'
tasks.split(',')
# Out:
# ['get gloves', 'get cat vitamins', 'call ambukance']

# %%
tasks.split()
# Out:
# ['get', 'gloves,get', 'cat', 'vitamins,call', 'ambukance']

# %% [markdown]
# #用join()結合

# %%
crypto_list=['Yeti','Bigfoot','Loch Ness Monster']
crypto_string=', '.join(crypto_list)
print("Found and signing book deals:",crypto_string)
# Out:
# Found and signing book deals: Yeti, Bigfoot, Loch Ness Monster

# %% [markdown]
# #用replace()來替換

# %%
setup="a duck goes into a bar..."
setup.replace('duck','marmoset')
# Out:
# 'a marmoset goes into a bar...'

# %%
setup
# Out:
# 'a duck goes into a bar...'

# %%
setup.replace('a','a famous',2)
# Out:
# 'a famous duck goes into a famous bar...'

# %% [markdown]
# #用strip()移除空白字元(' ','\t','\n')

# %%
world="    earth !"
world.strip()
# Out:
# 'earth !'

# %%
world.lstrip()
# Out:
# 'earth !'

# %%
world.rstrip()
# Out:
# '    earth !'

# %%
world.strip('!')
# Out:
# '    earth '

# %%
blurt="What the...!!?"
blurt.strip('.!?')
# Out:
# 'What the'

# %%
import string
string.whitespace
# Out:
# ' \t\n\r\x0b\x0c'

# %%
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
blurt='what the...!!?'
blurt.strip(string.punctuation)
# Out:
# 'what the'

# %%
prospector="what in tarnation ...??!!"
prospector.strip(string.whitespace+string.punctuation)
# Out:
# 'what in tarnation'

# %%
poem='''All that doth flow we cannot liquid name
...Or else would fire and watr be the same;
...But that is liquid which is moist and wet
...Fire that property can never get.
...Then 'tis not cold that doth the fire put out
...But 'tis the wet that makes it die, no doubt.'''
poem[:13]
# Out:
# 'All that doth'

# %%
len(poem)
# Out:
# 264

# %%
poem.startswith('All')
# Out:
# True

# %%
poem.endswith('That\'s all,folks')
# Out:
# False

# %%
word='that'
poem.find(word)
# Out:
# 4

# %%
poem.index(word)
# Out:
# 4

# %%
word='the'
poem.rfind(word)
# Out:
# 228

# %%
poem.rindex(word)
# Out:
# 228

# %%
word='duck'
poem.find(word)
# Out:
# -1

# %%
poem.index(word)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-83-c4456b6bd3bf> in <module>
# ----> 1 poem.index(word)
#
# ValueError: substring not found

# %%
word='the'
poem.count(word)

# %% [markdown]
# #詩的字元是否只有字母與數字

# %%
poem.isalnum()

# %%
setup='a duck goes into a bar...'
setup.strip('.')

# %%
setup.capitalize()

# %%
setup.title()

# %%
setup.upper()

# %%
setup.lower()

# %%
setup.swapcase()

# %%
setup.center(30)

# %%
setup.ljust(30)

# %%
setup.rjust(30)

# %% [markdown]
# #  %s字串

# %%
'%s' % 42

# %% [markdown]
# #  %d十進制整數

# %%
'%d'%42

# %% [markdown]
# #  %x十六進制整數

# %%
'%x'%42

# %% [markdown]
# #  %o八進制整數

# %%
'%o'%42

# %%
'%s'%7.03

# %%
'%.3f'%7.03

# %% [markdown]
# #  %e指數浮點數

# %%
'%e'%7.03

# %% [markdown]
# #  %g十進制或指數浮點數

# %%
'%g'%7.03

# %% [markdown]
# #  %%常值%

# %%
'%.1f%%'%100

# %%
actor='Richard Gere'
cat='Chester'
weight=28
"My wife's favorite actor is %s"%actor

# %%
"Our cat %s weights %d pounds"%(cat,weight)

# %%
thing = 'woodchuck'
'%s'%thing

# %%
'%12s'%thing

# %%
'%+12s'%thing

# %%
'%-12s'%thing

# %%
'%.3s'%thing

# %%
'%12.3s'%thing

# %%
'%-12.3s'%thing

# %%
thing=98.6
'%f'%thing

# %%
'%12f'%thing

# %%
'%+12f'%thing

# %%
'%-12f'%thing

# %%
'%.3f'%thing

# %%
'%+12.3f'%thing

# %%
'%-12.3f'%thing

# %%
thing=9876
'%d'%thing

# %%
'%12d'%thing

# %%
'%12d'%thing

# %%
'%+12d'%thing

# %%
'%-12d'%thing

# %%
'%.3d'%thing

# %%
'%12.3d'%thing

# %%
'%-12.3d'%thing

# %%
thing='woodchuck'
'{}'.format(thing)

# %%
thing='woodchuck'
place='lake'
'The {} is in the {}.'.format(thing,place)

# %%
'The {1} is in the {0}.'.format(thing,place)

# %%
'The {thing} is in the {place}.'.format(thing='duck',place='bathtub')

# %%
d={'thing':'duck','place':'bathtub'}
'The {0[thing]} is in the {0[place]}.'.format(d)

# %%
thing = 'wraith'
place = 'window'
'The {} is at the {}'.format(thing,place)

# %%
'The {:10s} is at the {:10s}'.format(thing,place)

# %%
'The {:<10s} is at the {:<10s}'.format(thing,place)

# %%
'The {:^10s} is at the {:^10s}'.format(thing,place)

# %%
'The {:>10s} is at the {:>10s}'.format(thing,place)

# %%
'The {:!^10s} is at the {:!^10s}'.format(thing,place)

# %%
thing = 'weereduck'
place = 'werepond'
f'The {thing} is in the {place}'

# %%
f'The {thing.capitalize()} is in the {place.rjust(20)}'

# %%
f'The {thing:>20s} is in the {place:^20s}'

# %%
a=10.234
f'The {thing:*>20s} is in the {place:$^20s} at {a:@^10.2f}'
