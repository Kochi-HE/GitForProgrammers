# %%
bool(True)
# Out:
# True

# %%
bool(1)
# Out:
# True

# %%
bool(45)
# Out:
# True

# %%
bool(-45)
# Out:
# True

# %%
bool(False)
# Out:
# False

# %%
bool(0)
# Out:
# False

# %%
bool(0.0)
# Out:
# False

# %%
5
# Out:
# 5

# %%
0
# Out:
# 0

# %%
123
# Out:
# 123

# %%
+123
# Out:
# 123

# %%
-123
# Out:
# -123

# %%
1,000,000
# Out:
# (1, 0, 0)

# %%
million=1_000_000
million
# Out:
# 1000000

# %%
1_2_3
# Out:
# 123

# %%
5+9
# Out:
# 14

# %%
100-7
# Out:
# 93

# %%
4-10
# Out:
# -6

# %%
5+9+3
# Out:
# 17

# %%
4+3-2-1+6
# Out:
# 10

# %%
5+9    +    3
# Out:
# 17

# %%
6*7
# Out:
# 42

# %%
7+6
# Out:
# 13

# %%
6*7*2*3
# Out:
# 252

# %% [markdown]
# #捨棄餘數

# %%
9//5
# Out:
# 1

# %%
a=95
a
# Out:
# 95

# %%
a-3
a
# Out:
# 95

# %%
a=a-3
a
# Out:
# 92

# %%
a=95
temp=a-3
a=temp
a
# Out:
# 92

# %%
a=92
a+=8
a
# Out:
# 100

# %%
a=100
a*=2
a
# Out:
# 200

# %%
a=200
a/=3
a
# Out:
# 66.66666666666667

# %%
a=13
a//=4
a
# Out:
# 3

# %%
9%5
# Out:
# 4

# %%
divmod(9,5)
# Out:
# (1, 4)

# %%
9//5
# Out:
# 1

# %%
9%5
# Out:
# 4

# %%
2**3
# Out:
# 8

# %%
2.0**3
# Out:
# 8.0

# %%
2**3.0
# Out:
# 8.0

# %%
0**3
# Out:
# 0

# %%
2+3*4
# Out:
# 14

# %%
2+(3*4)
# Out:
# 14

# %%
-5**2
# Out:
# -25

# %%
-(5**2)
# Out:
# -25

# %%
(-5)**2
# Out:
# 25

# %%
10
# Out:
# 10

# %%
0b10
# Out:
# 2

# %%
0o10
# Out:
# 8

# %%
0x10
# Out:
# 16

# %%
value=65
bin(value)
# Out:
# '0b1000001'

# %%
oct(value)
# Out:
# '0o101'

# %%
hex(value)
# Out:
# '0x41'

# %%
chr(value)
# Out:
# 'A'

# %%
ord(chr(value))
# Out:
# 65

# %%
int(True)
# Out:
# 1

# %%
int(False)
# Out:
# 0

# %%
bool(0)
# Out:
# False

# %%
bool(1)
# Out:
# True

# %%
int(98.6)
# Out:
# 98

# %%
int(1.0e4)
# Out:
# 10000

# %%
bool(1.0)
# Out:
# True

# %%
bool(0.0)
# Out:
# False

# %%
int('99')
# Out:
# 99

# %%
int('-23')
# Out:
# -23

# %%
int('+12')
# Out:
# 12

# %%
int('1_000_000')
# Out:
# 1000000

# %%
int('10',2)
# Out:
# 2

# %%
int('10',8)
# Out:
# 8

# %%
int('10',16)
# Out:
# 16

# %%
int('10',22)
# Out:
# 22

# %%
int(12345)
# Out:
# 12345

# %% [markdown]
# int()無法處理含有小數點或指數的字串

# %%
int('99.9')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-73-970a435df49f> in <module>
# ----> 1 int('99.9')
#
# ValueError: invalid literal for int() with base 10: '99.9'

# %%
4+7.0

# %%
True+2

# %%
False+5.0

# %%
googol=10**100
googol

# %%
googol*googol

# %%
555.

# %%
5.0

# %%
05.0

# %%
5e0

# %%
5e1

# %%
5.0e1

# %%
5.0*(10**1)

# %%
million=1_000_000
million

# %%
1.0_0_1

# %%
float(True)

# %%
float(False)

# %%
float(99)

# %%
float('999')

# %%
float('98.6')

# %%
float('-1.5')

# %%
float('1.0e4')

# %%
43+2.

# %%
False+0

# %%
False+0.

# %%
True+0

# %%
True+0.

# %%
60*60

# %%
seconds_per_hour=60*60

# %%
24*seconds_per_hour

# %%
seconds_per_day=24*seconds_per_hour

# %%
seconds_per_day/seconds_per_hour

# %%
seconds_per_day//seconds_per_hour
