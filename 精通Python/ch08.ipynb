# %%
empty_dict={}
empty_dict
# Out:
# {}

# %%
bierce={
       "day":"A period of twenty-four hours, mostly misspent",
       "positive":"Mistaken at the top of one's voice",
       "misfortune":"The kind if fortune that never misses"
       }
bierce
# Out:
# {'day': 'A period of twenty-four hours, mostly misspent',
#  'positive': "Mistaken at the top of one's voice",
#  'misfortune': 'The kind if fortune that never misses'}

# %%
acme_customer={'first':'Wile','middle':'E','last':'Coyote'}
acme_customer
# Out:
# {'first': 'Wile', 'middle': 'E', 'last': 'Coyote'}

# %%
acme_customer=dict(first='Wile',middle='E',last='Coyote')
acme_customer
# Out:
# {'first': 'Wile', 'middle': 'E', 'last': 'Coyote'}

# %%
lol=[['a','b'],['c','d'],['e','f']]
dict(lol)
# Out:
# {'a': 'b', 'c': 'd', 'e': 'f'}

# %%
lol=[('a','b'),('c','d'),('e','f')]
dict(lol)
# Out:
# {'a': 'b', 'c': 'd', 'e': 'f'}

# %%
tol=(['a','b'],['c','d'],['e','f'])
dict(tol)
# Out:
# {'a': 'b', 'c': 'd', 'e': 'f'}

# %%
los=['ab','cd','ef']
dict(los)
# Out:
# {'a': 'b', 'c': 'd', 'e': 'f'}

# %%
tos=('ab','cd','ef')
dict(tos)
# Out:
# {'a': 'b', 'c': 'd', 'e': 'f'}

# %%
pythons={
        'Chapman':'Graham',
        'Cleese':'John',
        'Idle':'Eric',
        'Jones':'Terry',
        'Palin':'Michael'
        }
pythons
# Out:
# {'Chapman': 'Graham',
#  'Cleese': 'John',
#  'Idle': 'Eric',
#  'Jones': 'Terry',
#  'Palin': 'Michael'}

# %%
pythons['Gilliam']='Gerry'
pythons
# Out:
# {'Chapman': 'Graham',
#  'Cleese': 'John',
#  'Idle': 'Eric',
#  'Jones': 'Terry',
#  'Palin': 'Michael',
#  'Gilliam': 'Gerry'}

# %%
pythons['Gilliam']='Terry'
pythons
# Out:
# {'Chapman': 'Graham',
#  'Cleese': 'John',
#  'Idle': 'Eric',
#  'Jones': 'Terry',
#  'Palin': 'Michael',
#  'Gilliam': 'Terry'}

# %%
some_pythons={
             'Graham':'Chapman',
             'John':'Cleese',
             'Eric':'Idle',
             'Terry':'Gilliam',
             'Micheal':'Palin',
             'Terry':'Jones'
             }
some_pythons
# Out:
# {'Graham': 'Chapman',
#  'John': 'Cleese',
#  'Eric': 'Idle',
#  'Terry': 'Jones',
#  'Micheal': 'Palin'}

# %%
some_pythons['John']
# Out:
# 'Cleese'

# %%
'Eric' in some_pythons
# Out:
# True

# %%
some_pythons.get('John')
# Out:
# 'Cleese'

# %%
some_pythons.get('Groucho','Not a Python')
# Out:
# 'Not a Python'

# %%
some_pythons.get('Groucho')

# %%
signals={'green':'go','yellow':'go faster','red':'smile for the camera'}
signals.keys()
# Out:
# dict_keys(['green', 'yellow', 'red'])

# %%
list(signals.keys())
# Out:
# ['green', 'yellow', 'red']

# %%
list(signals.values())
# Out:
# ['go', 'go faster', 'smile for the camera']

# %%
list(signals.items())
# Out:
# [('green', 'go'), ('yellow', 'go faster'), ('red', 'smile for the camera')]

# %%
len(signals)
# Out:
# 3

# %%
first={'a':'agony','b':'bliss'}
second={'b':'bagels','c':'candy'}
{**first,**second}
# Out:
# {'a': 'agony', 'b': 'bagels', 'c': 'candy'}

# %%
pythons={
        'Chapman':'Graham',
        'Cleese':'John',
        'Gilliam':'Terry',
        'Idle':'Eric',
        'Jones':'Terry',
        'Palin':'Michael'
        }
pythons
# Out:
# {'Chapman': 'Graham',
#  'Cleese': 'John',
#  'Gilliam': 'Terry',
#  'Idle': 'Eric',
#  'Jones': 'Terry',
#  'Palin': 'Michael'}

# %%
others={'Marx':'Groucho','Howard':'Moe'}
others
# Out:
# {'Marx': 'Groucho', 'Howard': 'Moe'}

# %% [markdown]
# # 用update()結合字典

# %%
pythons.update(others)
pythons
# Out:
# {'Chapman': 'Graham',
#  'Cleese': 'John',
#  'Gilliam': 'Terry',
#  'Idle': 'Eric',
#  'Jones': 'Terry',
#  'Palin': 'Michael',
#  'Marx': 'Groucho',
#  'Howard': 'Moe'}

# %%
first={'a':1,'b':2}
second={'b':'platypus'}
first.update(second)
first
# Out:
# {'a': 1, 'b': 'platypus'}

# %%
del pythons['Marx']
pythons
# Out:
# {'Chapman': 'Graham',
#  'Cleese': 'John',
#  'Gilliam': 'Terry',
#  'Idle': 'Eric',
#  'Jones': 'Terry',
#  'Palin': 'Michael',
#  'Howard': 'Moe'}

# %%
del pythons['Howard']
pythons
# Out:
# {'Chapman': 'Graham',
#  'Cleese': 'John',
#  'Gilliam': 'Terry',
#  'Idle': 'Eric',
#  'Jones': 'Terry',
#  'Palin': 'Michael'}

# %%
len(pythons)
# Out:
# 6

# %%
pythons.pop('Palin')
pythons
# Out:
# {'Chapman': 'Graham',
#  'Cleese': 'John',
#  'Gilliam': 'Terry',
#  'Idle': 'Eric',
#  'Jones': 'Terry'}

# %%
len(pythons)
# Out:
# 5

# %%
pythons.pop('First','Hugo')
# Out:
# 'Hugo'

# %%
len(pythons)
# Out:
# 5

# %%
pythons.clear()
pythons
# Out:
# {}

# %%
pythons={}
pythons
# Out:
# {}

# %%
pythons={'Chapman':'Graham','Cleese':'John','Jones':'Terry','Palin':'Michael','Idle':'Eric'}
'Chapman' in pythons
# Out:
# True

# %%
'Palin' in pythons
# Out:
# True

# %%
'Gilliam' in pythons
# Out:
# False

# %%
signals={'green':'go','yellow':'go faster','red':'smile for the camera'}
save_signals=signals
signals['blue']='confuse everyone'
save_signals
# Out:
# {'green': 'go',
#  'yellow': 'go faster',
#  'red': 'smile for the camera',
#  'blue': 'confuse everyone'}

# %%
signals={'green':'go','yellow':'go faster','red':'smile for the camera'}
original_signals=signals.copy()
original_signals
# Out:
# {'green': 'go', 'yellow': 'go faster', 'red': 'smile for the camera'}

# %%
signals['blue']='confuse everyone'
original_signals
# Out:
# {'green': 'go', 'yellow': 'go faster', 'red': 'smile for the camera'}

# %%
signals={'green':'go','yellow':'go faster','red':['stop','smile']}
signals_copy=signals.copy()
signals_copy
# Out:
# {'green': 'go', 'yellow': 'go faster', 'red': ['stop', 'smile']}

# %%
signals['red'][1]='sweat'
signals
# Out:
# {'green': 'go', 'yellow': 'go faster', 'red': ['stop', 'sweat']}

# %%
signals_copy
# Out:
# {'green': 'go', 'yellow': 'go faster', 'red': ['stop', 'sweat']}

# %%
import copy
signals={'green':'go','yellow':'go faster','red':['stop','smile']}
signals_copy=copy.deepcopy(signals)
signals
# Out:
# {'green': 'go', 'yellow': 'go faster', 'red': ['stop', 'smile']}

# %%
signals_copy
# Out:
# {'green': 'go', 'yellow': 'go faster', 'red': ['stop', 'smile']}

# %%
signals['red'][1]='sweat'
signals
# Out:
# {'green': 'go', 'yellow': 'go faster', 'red': ['stop', 'sweat']}

# %%
signals_copy
# Out:
# {'green': 'go', 'yellow': 'go faster', 'red': ['stop', 'smile']}

# %%
a={1:1,2:2,3:3}
b={3:3,1:1,2:2}
a==b
# Out:
# True

# %%
a={1:[1,2],2:[1],3:[1]}
b={1:[1,1],2:[1],3:[1]}
a==b
# Out:
# False

# %%
accusation={'room':'ballroom','weapon':'lear pipe','person':'Col. Mustard'}
for card in accusation:
    print(card)
# Out:
# room
# weapon
# person

# %%
for value in accusation.values():
    print(value)
# Out:
# ballroom
# lear pipe
# Col. Mustard

# %%
for item in accusation.items():
    print(item)
# Out:
# ('room', 'ballroom')
# ('weapon', 'lear pipe')
# ('person', 'Col. Mustard')

# %%
for card,contents in accusation.items():
    print('Card',card,'has the contents',contents)
# Out:
# Card room has the contents ballroom
# Card weapon has the contents lear pipe
# Card person has the contents Col. Mustard

# %%
word='letters'
letter_counts={letter:word.count(letter)for letter in word}
letter_counts
# Out:
# {'l': 1, 'e': 2, 't': 2, 'r': 1, 's': 1}

# %%
word='letters'
letter_counts={letter:word.count(letter)for letter in set(word)}
letter_counts
# Out:
# {'l': 1, 's': 1, 't': 2, 'e': 2, 'r': 1}

# %%
vowels='aeiou'
word='onomatopoeia'
vowel_counts={letter:word.count(letter)for letter in set(word) if letter in vowels}
vowel_counts
# Out:
# {'o': 4, 'a': 2, 'e': 1, 'i': 1}

# %%
empty_set=set()
empty_set
# Out:
# set()

# %%
even_numbers=(0,2,4,6,8)
even_numbers
# Out:
# (0, 2, 4, 6, 8)

# %%
odd_numbers=(1,3,5,7,9)
odd_numbers
# Out:
# (1, 3, 5, 7, 9)

# %%
set('letters')
# Out:
# {'e', 'l', 'r', 's', 't'}

# %%
set(['Dasher','Dancer','Prancer','Mason-Dixon'])
# Out:
# {'Dancer', 'Dasher', 'Mason-Dixon', 'Prancer'}

# %%
set(('Ummagumma','Echoes','Atom Heart Mother'))
# Out:
# {'Atom Heart Mother', 'Echoes', 'Ummagumma'}

# %%
set({'apple':'red','oramge':'orange','cherry':'red'})
# Out:
# {'apple', 'cherry', 'oramge'}

# %%
reindeer=set(['Dasher','Dancer','Prancer','Mason-Dixon'])
len(reindeer)
# Out:
# 4

# %%
s=set((1,2,3))
s
# Out:
# {1, 2, 3}

# %%
s.add(4)
s
# Out:
# {1, 2, 3, 4}

# %%
s=set((1,2,3))
s.remove(3)
s
# Out:
# {1, 2}

# %%
furniture=set(('sofa','ottoman','table'))
for piece in furniture:
    print(piece)
# Out:
# ottoman
# sofa
# table

# %%
drinks={'martinal':{'vodka','vermouth'},
        'black russian':{'vodka','kahlua'},
        'white russian':{'cream','kahlua','vodka'},
        'manhattan':{'rye','vermouth','bitters'},
        'screwdriver':{'orange juice','vodka'}
       }
for name,contents in drinks.items():
    if 'vodka' in contents:
        print(name)
# Out:
# martinal
# black russian
# white russian
# screwdriver

# %%
for name,contents in drinks.items():
    if 'vodka' in contents and not ('vermouth' in contents or 'cream' in contents):
        print(name)
# Out:
# black russian
# screwdriver

# %%
for name,contents in drinks.items():
    if contents & {'vermouth','orange juice'}:
        print(name)
# Out:
# martinal
# manhattan
# screwdriver

# %%
for name,contents in drinks.items():
    if 'vodka' in contents and not contents&{'vermouth','cream'}:
        print(name)
# Out:
# black russian
# screwdriver

# %%
bruss=drinks['black russian']
wruss=drinks['white russian']

# %%
a={1,2}
b={2,3}
a&b
# Out:
# {2}

# %%
a.intersection(b)
# Out:
# {2}

# %%
a|b
# Out:
# {1, 2, 3}

# %%
a.union(b)
# Out:
# {1, 2, 3}

# %%
bruss|wruss
# Out:
# {'cream', 'kahlua', 'vodka'}

# %%
a-b
# Out:
# {1}

# %%
a.difference(b)
# Out:
# {1}

# %%
bruss-wruss
# Out:
# set()

# %%
wruss-bruss
# Out:
# {'cream'}

# %% [markdown]
# # 互斥或使用^或symmetric_difference()

# %%
a^b
# Out:
# {1, 3}

# %%
a.symmetric_difference(b)
# Out:
# {1, 3}

# %%
bruss^wruss
# Out:
# {'cream'}

# %% [markdown]
# # 可用<=或issubset()來查看一個集合是不是另一個集合的子集合

# %%
a<=b
# Out:
# False

# %%
a.issubset(b)
# Out:
# False

# %%
bruss<=wruss
# Out:
# True

# %%
a<=b
# Out:
# False

# %%
a.issubset(b)
# Out:
# False

# %% [markdown]
# # 真子集可用<來計算

# %%
a<b
# Out:
# False

# %%
a<a
# Out:
# False

# %%
bruss<wruss
# Out:
# True

# %% [markdown]
# # 超集合是子集合的相反，可用>=或issuperset()

# %%
a>=b
# Out:
# False

# %%
a.issuperset(b)
# Out:
# False

# %%
wruss>=bruss
# Out:
# True

# %%
a>=a
# Out:
# True

# %%
a.issuperset(a)
# Out:
# True

# %% [markdown]
# # 真超集合

# %%
a>b
# Out:
# False

# %%
wruss>bruss
# Out:
# True

# %%
a>a
# Out:
# False

# %%
a_set={number for number in range(1,6) if number%3==1}
a_set
# Out:
# {1, 4}

# %% [markdown]
# # 用frozenset建立不可變集合

# %%
frozenset([3,2,1])
# Out:
# frozenset({1, 2, 3})

# %%
frozenset(set([2,1,3]))
# Out:
# frozenset({1, 2, 3})

# %%
frozenset({3,1,2})
# Out:
# frozenset({1, 2, 3})

# %%
frozenset((2,3,1))
# Out:
# frozenset({1, 2, 3})

# %%
marx_list=['Groucho','Chico','Harpo']
marx_tuple=('Groucho','Chico','Harpo')
marx_dict={'Groucho':'banjo','Chico':'piano','Harpo':'harp'}
marx_set={'Groucho','Chico','Harpo'}
marx_list[2]
# Out:
# 'Harpo'

# %%
marx_tuple[2]
# Out:
# 'Harpo'

# %%
marx_dict['Harpo']
# Out:
# 'harp'

# %%
'Harpo' in marx_list
# Out:
# True

# %%
'Harpo' in marx_tuple
# Out:
# True

# %%
'Harpo' in marx_dict
# Out:
# True

# %%
'Harpo' in marx_set
# Out:
# True

# %%
marxes=['Groucho','Chico','Harpo']
pythons=['Chapman','Cleese','Gilliam','Jones','Palin']
stooges=['Moe','Curly','Larry']

# %%
tuple_of_lists=marxes,pythons,stooges
tuple_of_lists
# Out:
# (['Groucho', 'Chico', 'Harpo'],
#  ['Chapman', 'Cleese', 'Gilliam', 'Jones', 'Palin'],
#  ['Moe', 'Curly', 'Larry'])

# %%
list_of_lists=[marxes,pythons,stooges]
list_of_lists
# Out:
# [['Groucho', 'Chico', 'Harpo'],
#  ['Chapman', 'Cleese', 'Gilliam', 'Jones', 'Palin'],
#  ['Moe', 'Curly', 'Larry']]

# %%
dict_of_lists={'Marxes':marxes,'Pythons':pythons,'Stooges':stooges}
dict_of_lists
# Out:
# {'Marxes': ['Groucho', 'Chico', 'Harpo'],
#  'Pythons': ['Chapman', 'Cleese', 'Gilliam', 'Jones', 'Palin'],
#  'Stooges': ['Moe', 'Curly', 'Larry']}

# %%
houses={(44.79,-93.14,285):'My House',(38.89,-77.03,13):'The White House'}
houses
# Out:
# {(44.79, -93.14, 285): 'My House', (38.89, -77.03, 13): 'The White House'}
