# %%
x=5
y=x+12
y
# Out:
# 17

# %%
y=5
x=12-y
x
# Out:
# 7

# %%
a=7
print(a)
# Out:
# 7

# %%
b=a
print(b)
# Out:
# 7

# %%
print(type(7))
# Out:
# <class 'int'>

# %%
print(type(7)==int)
# Out:
# True

# %%
print(isinstance(7,int))
# Out:
# True

# %%
a=7
b=a
print(type(a))
# Out:
# <class 'int'>

# %%
print(type(b))
# Out:
# <class 'int'>

# %%
print(type(58))
# Out:
# <class 'int'>

# %%
print(type(99.9))
# Out:
# <class 'float'>

# %%
print(type('abc'))
# Out:
# <class 'str'>

# %%
y=5
x=12-y
x
# Out:
# 7

# %%
two=deux=zwei=2
two
# Out:
# 2

# %%
deux
# Out:
# 2

# %%
zwei
# Out:
# 2

# %%
x=5
x
# Out:
# 5

# %%
y=x
y
# Out:
# 5

# %%
x=29
x
# Out:
# 29

# %%
y
# Out:
# 5

# %%
a=[2,4,6]
b=a
a
# Out:
# [2, 4, 6]

# %%
b
# Out:
# [2, 4, 6]

# %%
a[0]=99
a
# Out:
# [99, 4, 6]

# %%
b
# Out:
# [99, 4, 6]

# %%
prince=99
prince
# Out:
# 99

# %%
print(type(5))
# Out:
# <class 'int'>

# %%
print(type(2.0))
# Out:
# <class 'float'>

# %%
print(type(5+2.0))
# Out:
# <class 'float'>

# %%
print("更新程式1_Book1")
# Out:
# 更新程式1_Book1

# %%
print("更新程式2_Book1")
# Out:
# 更新程式2_Book1

# %%
print("更新程式3_Book1")
# Out:
# 更新程式3_Book1

# %%
print("更新程式4_Book1")
# Out:
# 更新程式4_Book1
